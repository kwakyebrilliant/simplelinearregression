# %% [markdown]
# # CODE TO PERFORM SIMPLE LINEAR REGRESSION
# # Brilliant
# ![image.png](attachment:image.png)

# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# You own an ice cream business and you would like to create a model that could predict the daily revenue in dollars based on the outside air temperature (degC). You decide that a Linear Regression model might be a good candidate to solve this problem.
# Data set:
# - Independant variable X: Outside Air Temperature
# - Dependant variable Y: Overall daily revenue generated in dollars

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # STEP #1: LIBRARIES IMPORT

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # STEP #2: IMPORT DATASET

# %%
#Import data
IceCream = pd.read_csv("IceCreamData.csv")

# %%
IceCream.head(10)
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194
# 5    14.352514  367.940744
# 6    13.707780  308.894518
# 7    30.833985  696.716640
# 8     0.976870   55.390338
# 9    31.669465  737.800824

# %%
IceCream.tail(10)
# Out:
#      Temperature     Revenue
# 490    23.824922  584.399945
# 491    34.472169  809.352519
# 492    23.056214  552.819351
# 493    14.931506  377.430928
# 494    25.112066  571.434257
# 495    22.274899  524.746364
# 496    32.893092  755.818399
# 497    12.588157  306.090719
# 498    22.362402  566.217304
# 499    28.957736  655.660388

# %%
IceCream.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
IceCream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %% [markdown]
# # STEP#3: VISUALIZE DATASET

# %%
sns.jointplot(x='Temperature', y='Revenue', data = IceCream, color = '#0EA71A')

# %%
sns.jointplot(x='Revenue', y='Temperature', data = IceCream, color = '#0E10A7')

# %%
sns.pairplot(IceCream)

# %%
sns.lmplot(x='Temperature', y='Revenue', data=IceCream)

# %% [markdown]
# # STEP#4: CREATE TESTING AND TRAINING DATASET

# %%
y = IceCream['Revenue']

# %%
y
# Out:
# 0      534.799028
# 1      625.190122
# 2      660.632289
# 3      487.706960
# 4      316.240194
#           ...
# 495    524.746364
# 496    755.818399
# 497    306.090719
# 498    566.217304
# 499    655.660388
# Name: Revenue, Length: 500, dtype: float64

# %%
X = IceCream[['Temperature']]

# %%
X
# Out:
#      Temperature
# 0      24.566884
# 1      26.005191
# 2      27.790554
# 3      20.595335
# 4      11.503498
# ..           ...
# 495    22.274899
# 496    32.893092
# 497    12.588157
# 498    22.362402
# 499    28.957736
#
# [500 rows x 1 columns]

# %%
#Import train_test_split class
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
X_train
# Out:
#      Temperature
# 249    18.148952
# 173    35.217240
# 444    45.000000
# 395    30.407615
# 36     22.284550
# ..           ...
# 43     14.109661
# 199    25.241148
# 254    28.335363
# 30     24.183937
# 140    36.702572
#
# [375 rows x 1 columns]

# %%
X_test
# Out:
#      Temperature
# 373    20.103900
# 165    13.301796
# 299     7.745286
# 424    19.113653
# 370    18.883719
# ..           ...
# 320    15.118197
# 45     15.676487
# 375    29.251123
# 347    24.960446
# 483    27.281064
#
# [125 rows x 1 columns]

# %% [markdown]
# # STEP#5: TRAIN THE MODEL

# %%
X_train.shape
# Out:
# (375, 1)

# %%
#Linear Regression Class import
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression(fit_intercept = True)

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coefficient (m): ', regressor.coef_)
# Out:
# Linear Model Coefficient (m):  [21.45769881]

# %%
print('Linear Model Coefficient (b): ', regressor.intercept_)
# Out:
# Linear Model Coefficient (b):  44.1875274791941

# %% [markdown]
# # STEP#6: TEST THE MODEL

# %%
X_test.shape
# Out:
# (125, 1)

# %%
y_predict = regressor.predict( X_test)

# %%
y_predict
# Out:
# array([475.57096873, 329.61346723, 210.38354081, 454.32253269,
#        449.38868054, 627.5324571 , 468.51671248, 174.9485383 ,
#        360.46436618, 572.37390486, 422.63560446, 631.60063724,
#        483.53439433, 788.29860427, 676.41257551, 350.75787484,
#        575.88087154, 456.06701035, 479.02805421, 310.97409124,
#        316.45202932, 682.94510133, 359.31410135, 418.73512826,
#        199.99935436, 519.93043516, 530.81723962, 783.88095139,
#        525.87067807, 402.61374885, 169.12138133, 620.86217328,
#        232.06156682, 554.05326282, 757.67530177, 468.60726054,
#        673.15586438, 292.99174892, 469.36406993, 575.87064931,
#        585.51749833, 558.29922342, 728.50503824, 135.0923169 ,
#        423.06266932, 539.59566295, 636.39998181, 238.89121568,
#        689.74646529, 503.90923553, 303.02048876, 254.09490733,
#        622.33599597, 564.38893659, 313.94328358, 675.7000164 ,
#        243.94466149, 570.52026095, 408.9231086 , 122.82290351,
# ...

# %%
y_test
# Out:
# 373    491.430500
# 165    335.815687
# 299    198.121563
# 424    445.772400
# 370    444.826802
#           ...
# 320    374.955702
# 45     396.935648
# 375    697.147473
# 347    564.310532
# 483    612.241963
# Name: Revenue, Length: 125, dtype: float64

# %%
#VISUALIZE TRAIN RESULTS
plt.scatter(X_train, y_train, color = '#0E10A7')
plt.plot(X_train, regressor.predict(X_train), color = 'red')
plt.ylabel('Revenue [dollars]')
plt.xlabel('Temperature [degC]')
plt.title('Revenue Generated vs. Temperature @Ice Cream Stand(Training dataset)')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Temperature @Ice Cream Stand(Training dataset)')

# %%
# VISUALIZE TEST SET RESULTS
plt.scatter(X_test, y_test, color = '#0EA71A')
plt.plot(X_test, regressor.predict(X_test), color = 'black')
plt.ylabel('Revenue [dollars]')
plt.xlabel('Hours')
plt.title('Revenue Generated vs. Hours @Ice Cream Stand(Test dataset)')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Hours @Ice Cream Stand(Test dataset)')

# %% [markdown]
# # EXCELLENT JOB! NOW YOU BECAME EXPERT IN SIMPLE LINEAR REGRESSION
