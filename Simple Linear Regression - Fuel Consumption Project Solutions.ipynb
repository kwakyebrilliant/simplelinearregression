# %% [markdown]
# # CODE TO PERFORM SIMPLE LINEAR REGRESSION ON FUEL CONSUMPTION DATASET
# # Brilliant

# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# - You have been hired as a consultant to a major Automotive Manufacturer and you have been tasked to develop a model to predict the impact of increasing the vehicle horsepower (HP) on fuel economy (Mileage Per Gallon (MPG)). You gathered the data:
# - Data set:
#     - Independant variable X: Vehicle Horse Power
#     - Dependant variable Y: Mileage Per Gallon (MPG)

# %% [markdown]
# # STEP #1: LIBRARIES IMPORT

# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # STEP #2: IMPORT DATASET

# %%
#Import data
fueleconomy_df = pd.read_csv('FuelEconomy.csv')

# %%
fueleconomy_df.head(100)
# Out:
#     Horse Power  Fuel Economy (MPG)
# 0    118.770799           29.344195
# 1    176.326567           24.695934
# 2    219.262465           23.952010
# 3    187.310009           23.384546
# 4    218.594340           23.426739
# ..          ...                 ...
# 95   162.810542           27.418661
# 96   266.869640           15.989945
# 97   243.831211           19.253375
# 98   140.959803           29.515593
# 99   184.123053           25.196097
#
# [100 rows x 2 columns]

# %%
fueleconomy_df.head(5)
# Out:
#    Horse Power  Fuel Economy (MPG)
# 0   118.770799           29.344195
# 1   176.326567           24.695934
# 2   219.262465           23.952010
# 3   187.310009           23.384546
# 4   218.594340           23.426739

# %%
fueleconomy_df.tail(5)
# Out:
#     Horse Power  Fuel Economy (MPG)
# 95   162.810542           27.418661
# 96   266.869640           15.989945
# 97   243.831211           19.253375
# 98   140.959803           29.515593
# 99   184.123053           25.196097

# %%
fueleconomy_df.describe()
# Out:
#        Horse Power  Fuel Economy (MPG)
# count   100.000000          100.000000
# mean    213.676190           23.178501
# std      62.061726            4.701666
# min      50.000000           10.000000
# 25%     174.996514           20.439516
# 50%     218.928402           23.143192
# 75%     251.706476           26.089933
# max     350.000000           35.000000

# %%
fueleconomy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Horse Power         100 non-null    float64
#  1   Fuel Economy (MPG)  100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %% [markdown]
# # STEP#3: VISUALIZE DATASET

# %%
fueleconomy_df.head(4)
# Out:
#    Horse Power  Fuel Economy (MPG)
# 0   118.770799           29.344195
# 1   176.326567           24.695934
# 2   219.262465           23.952010
# 3   187.310009           23.384546

# %%
sns.jointplot(x = 'Horse Power', y = 'Fuel Economy (MPG)', data = fueleconomy_df)

# %%
sns.jointplot(x = 'Fuel Economy (MPG)', y = 'Horse Power', data = fueleconomy_df)

# %%
sns.pairplot(fueleconomy_df)

# %%
sns.lmplot(x = 'Horse Power', y =  'Fuel Economy (MPG)', data = fueleconomy_df)

# %%
sns.lmplot(x = 'Fuel Economy (MPG)', y =  'Horse Power', data = fueleconomy_df)

# %% [markdown]
# # STEP#4: CREATE TESTING AND TRAINING DATASET

# %%
X = fueleconomy_df[['Horse Power']]

# %%
y = fueleconomy_df['Fuel Economy (MPG)']

# %%
X
# Out:
#     Horse Power
# 0    118.770799
# 1    176.326567
# 2    219.262465
# 3    187.310009
# 4    218.594340
# ..          ...
# 95   162.810542
# 96   266.869640
# 97   243.831211
# 98   140.959803
# 99   184.123053
#
# [100 rows x 1 columns]

# %%
y
# Out:
# 0     29.344195
# 1     24.695934
# 2     23.952010
# 3     23.384546
# 4     23.426739
#         ...
# 95    27.418661
# 96    15.989945
# 97    19.253375
# 98    29.515593
# 99    25.196097
# Name: Fuel Economy (MPG), Length: 100, dtype: float64

# %%
X.shape
# Out:
# (100, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
X_train.shape
# Out:
# (70, 1)

# %%
X_test.shape
# Out:
# (30, 1)

# %% [markdown]
# # STEP#5: TRAIN THE MODEL

# %%
X_train.shape
# Out:
# (70, 1)

# %%
X_test.shape
# Out:
# (30, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression(fit_intercept = True)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coeff (m):', regressor.coef_)
print('Linear Model Coeff (b):', regressor.intercept_)
# Out:
# Linear Model Coeff (m): [-0.07427781]
# Linear Model Coeff (b): 39.08920497492252

# %% [markdown]
# # STEP#6: TEST THE MODEL

# %%
y_predict = regressor.predict(X_test)
y_predict
# Out:
# array([18.92711803, 22.69453747, 29.71452826, 19.63940489, 30.13990033,
#        25.08745042, 22.80287025, 29.88724717, 18.81836525, 25.83579462,
#        20.84957298, 13.09197305, 20.33016799, 18.09798173, 25.41294867,
#        29.2348005 , 22.19990833, 23.28742216, 29.31854526, 15.87796942,
#        23.33614226, 26.01785475, 15.24964246, 22.5119104 , 23.02431164,
#        26.99599523, 15.18358019, 26.95590059, 23.85877888, 26.16937426])

# %%
y_test
# Out:
# 6     17.163583
# 62    23.059180
# 8     28.718210
# 73    21.050399
# 11    29.678637
# 64    23.114161
# 2     23.952010
# 18    29.393330
# 54    20.898080
# 25    23.719583
# 66    19.139999
# 30    14.589079
# 39    20.407571
# 33    15.676316
# 99    25.196097
# 45    26.778148
# 92    24.181109
# 20    23.204745
# 93    29.397567
# 32    15.618956
# 63    21.726252
# 31    26.188478
# 77    15.441711
# 70    23.307192
# 82    21.595626
# 95    27.418661
# 10    17.300628
# 9     28.289516
# 91    25.286954
# 59    25.129650
# Name: Fuel Economy (MPG), dtype: float64

# %%
plt.scatter(X_train, y_train, color = 'gray')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.xlabel('Horse Power (HP)')
plt.ylabel('MPG')
plt.title('HP vs. MPG (Training Set)')
# Out:
# Text(0.5, 1.0, 'HP vs. MPG (Training Set)')

# %%
plt.scatter(X_test, y_test, color = '#0EA71A')
plt.plot(X_test, regressor.predict(X_test), color = 'black')
plt.xlabel('Horse Power (HP)')
plt.ylabel('MPG')
plt.title('HP vs. MPG (Testing Set)')
# Out:
# Text(0.5, 1.0, 'HP vs. MPG (Testing Set)')

# %%
HP = 500

# %% [markdown]
# # EXCELLENT JOB! NOW YOU BECAME EXPERT IN SIMPLE LINEAR REGRESSION
